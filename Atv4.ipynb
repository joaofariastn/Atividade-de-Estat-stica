# %%
import matplotlib.pyplot as plt

# %%
data = [9, 15, 16, 18, 18, 19, 21, 21, 23, 24, 25, 25, 25, 26, 26, 26, 26, 27, 30, 31, 32, 32, 32, 33, 33, 34, 35, 35, 37, 39, 40, 42]

# %%
# Junta media = 27,34
q1 = 22
q2 = 25
q3 = 33.5

# %%
plt.figure(figsize=(8,6))
plt.boxplot(data, vert=False, patch_artist=True, showmeans=True)
plt.title('Boxplot')
plt.xlabel('Valores')
plt.yticks([1], ['Dados'])
plt.grid(True)
plt.show()
